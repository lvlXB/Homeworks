# %% [markdown]
# <a href="https://colab.research.google.com/github/lvlXB/Homeworks/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab 2.

# %% [markdown]
# ![Снимок экрана 2025-03-21 в 14.28.30.png](data:image/png;base64,...)

# %% [markdown]
# Task 1.

# %%
x = float(input('x = '))
y = 0
if x < -3.2:
  y = x ** 4 + 9
else:
  y = (54 * x**4) / (-5 * x**2 + 7)
print(y)
# Out:
# x = -5
# 634.0

# %% [markdown]
# Task 2.

# %%
import math
a = float(input('a = '))
b = float(input('b = '))
c = float(input('c = '))
d = float(input('d = '))
m = math.sqrt(a**2 + b**2) # гипотенуза 1-ого треугольника
n = math.sqrt(c**2 + d**2) # гипотенуза 2-ого треугольника
s = a / c == b / d == m / n
print(s)
# Out:
# a = 15
# b = 20
# c = 3
# d = 4
# True

# %% [markdown]
# Task 3.

# %%
a1 = int(input('a1 = '))
a2 = int(input('a2 = '))
a3 = int(input('a3 = '))
a4 = int(input('a4 = '))
n = 0
if a1 == a2 == a3:
  n = 4
if a1 == a2 == a4:
  n = 3
if a1 == a3 == a4:
  n = 2
if a2 == a3 == a4:
  n = 1
print(n)
# Out:
# a1 = 1
# a2 = 1
# a3 = 2
# a4 = 1
# 3

# %% [markdown]
# Task 4a.

# %%
N = int(input('N = '))
t = N > 0 and N % 2 == 0
print(t)
# Out:
# N = 64568
# True

# %% [markdown]
# Task 4b.

# %%
N = int(input('N = '))
t = N > 0 and N % 10 == 7
print(t)
# Out:
# N = 1347
# True

# %% [markdown]
# Task 5.

# %%
a = int(input('a = '))
b = int(input('b = '))
c = int(input('c = '))
d = int(input('d = '))
e = int(input('e = '))
f = int(input('f = '))
