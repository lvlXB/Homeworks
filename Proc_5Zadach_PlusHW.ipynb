# %% [markdown]
# <a href="https://colab.research.google.com/github/lvlXB/Homeworks/blob/main/Proc_5Zadach_PlusHW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Proc10. Описать процедуру Swap(X, Y), меняющую содержимое переменных X и Y (X и Y — вещественные параметры, являющиеся одновременно входными и выходными). С ее помощью для данных переменных A, B, C, D последовательно поменять содержимое следующих пар: A и B, C и D, B и C и вывести новые значения A, B, C, D.

# %%
def swap(x, y):
  x, y = y, x
  return x, y

# %%
a = 2
b = 3
c = 4
d = 5
a1, b1 = swap(a, b)
c1, d1 = swap(c, d)
b2, c2 = swap(b1, c1)
print(a1, b2, c2, d1)
# Out:
# 3 5 2 4

# %% [markdown]
# Proc11. Описать процедуру Minmax(X, Y), записывающую в переменную X
# минимальное из значений X и Y, а в переменную Y — максимальное из этих значений (X и Y — вещественные параметры, являющиеся одновременно входными и выходными). Используя четыре вызова этой процедуры, найти минимальное и максимальное из данных чисел A, B, C, D.

# %%
def Minmax(x, y):
  if y < x:
    x, y = y, x
  return x, y

# %%
a = 7
b = 3
c = 13
d = 12
a1, b1 = Minmax(a, b)
c1, d1 = Minmax(c, d)
a2, c2 = Minmax(a1, c1)
b2, d2 = Minmax(b1, d1)
print(a2, d2)
# Out:
# 3 13

# %% [markdown]
# Proc18. Описать функцию CircleS(R) вещественного типа, находящую площадь круга радиуса R (R — вещественное). С помощью этой функции найти площади трех кругов с данными радиусами. Площадь круга радиуса R вычисляется по формуле S = π·R^2. В качестве значения π использовать 3.14.

# %%
def CircleS(R):
  S = 3.14 * R**2
  return S

# %%
r1 = 3
r2 = 5
r3 = 7
s1 = CircleS(r1)
s2 = CircleS(r2)
s3 = CircleS(r3)
print(s1, s2, s3)
# Out:
# 28.26 78.5 153.86

# %% [markdown]
# Proc21*. Описать функцию SumRange(A, B) целого типа, находящую сумму
# всех целых чисел от A до B включительно (A и B — целые). Если A > B,
# то функция возвращает 0. С помощью этой функции найти суммы чисел
# от A до B и от B до C, если даны числа A, B, C.

# %%
def SumRange(a, b):
  s = 0
  if a > b:
    s = 0
  else:
    for i in range(a, b + 1):
      s = s + i
  return s

# %%
A = int(input('A = '))
B = int(input('B = '))
C = int(input('C = '))
s1 = SumRange(A, B)
s2 = SumRange(B, C)
print(s1, s2)
# Out:
# A = 6
# B = 3
# C = 5
# 0 12

# %% [markdown]
# Proc28. Описать функцию IsPrime(N) логического типа, возвращающую TRUE, если целый параметр N (> 1) является простым числом, и FALSE в противном случае (число, большее 1, называется простым, если оно не имеет положительных делителей, кроме 1 и самого себя). Дан набор из 10 целых чисел, больших 1. С помощью функции IsPrime найти количество простых чисел в данном наборе.

# %%
def IsPrime(n):
  y = True
  for j in range(2, (n // 2) + 1):
    if n % j == 0:
      y = False
      break
  return y

# %%
s = 0
for i in range (1, 11):
  x = int(input())
  prost = IsPrime(x)
  print(prost)
  if prost == True:
    s = s + 1
print('Всего простых чисел в наборе:', s)
# Out:
# 13
# True
# 45
# False
# 59
# True
# 61
# True
# 99
# False
# 105
# False
# 125
# False
# 144
# False
# 256
# False
# 401
# True
# Всего простых чисел в наборе: 4

# %% [markdown]
# ![Снимок экрана 2025-04-11 в 15.57.40.png](data:image/png;base64,...)

# %% [markdown]
# Task 1.

# %% [markdown]
# Task 2.

# %% [markdown]
# Task 3.

# %%
kom = 12
summ = 12
day = 1
while summ <= 100:
  kom = kom * 1.2 + 2
  summ = summ + kom
  day += 1
print(day)
# Out:
# 5
